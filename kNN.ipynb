# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA
import numpy as np

# %matplotlib inline

# %%
data=pd.read_csv("/content/drive/My Drive/Colab Notebooks/data_2020cafe/data_inheo.csv")
data

# %%
data=data.dropna(axis=0)
data_delname=data.drop(['사업장명'],axis=1)
data_delname=data_delname.dropna(axis=0)

# %%
data_delname.info()

# %%
data_delname.columns=['whatever','size1_10','floor_012','dist_04','success_01','StartM','openY_123','gu1_25','sub_1_9','franch_012']

# %%
data_delname.head()

# %%
X=np.array(pd.DataFrame(data_delname,columns=['size1_10','floor_012','dist_04','StartM','openY_123','gu1_25','sub_1_9','franch_012']))

# %%
y=np.array(pd.DataFrame(data_delname,columns=['success_01']))

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X_train

# %%
#학습-PRUNING
rf_clf = RandomForestClassifier(n_estimators=10)
rf_clf = rf_clf.fit(X_train, y_train)
#extract single tree
estimator = rf_clf.estimators_[5]
#feature_names
feature_names = data_delname.columns.tolist()
feature_names = feature_names[1:4]+feature_names[5:]
#target_name
target_names = np.array(['success', 'fail'])

# %%
#아니다 하지말자. 변수가 너무 많다.
