# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

import numpy as np

# %%
import pandas as pd

# %%
test=pd.read_csv("/content/drive/My Drive/Colab Notebooks/data_2020cafe/설문지 정리.csv", encoding="cp949")
train_data=pd.read_csv("/content/drive/My Drive/Colab Notebooks/data_2020cafe/train_data_inheo.csv")
train=pd.read_csv("/content/drive/My Drive/Colab Notebooks/data_2020cafe/train_inheo.csv")

# %%
target=train['성공여부']

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21055 entries, 0 to 21054
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21055 non-null  int64
#  1   시설총규모       21055 non-null  float64
#  2   업소위치분기      21055 non-null  int64
#  3   distance    21055 non-null  float64
#  4   성공여부        21055 non-null  int64
#  5   창업월         21055 non-null  int64
#  6   구_1_25      21055 non-null  int64
#  7   프랜차이즈여부_02  21055 non-null  int64
#  8   sub_19      21055 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 1.4 MB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21055 entries, 0 to 21054
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21055 non-null  int64
#  1   시설총규모       21055 non-null  float64
#  2   업소위치분기      21055 non-null  int64
#  3   distance    21055 non-null  float64
#  4   창업월         21055 non-null  int64
#  5   구_1_25      21055 non-null  int64
#  6   프랜차이즈여부_02  21055 non-null  int64
#  7   sub_19      21055 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 1.3 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9 non-null      int64
#  1   사업장명        9 non-null      object
#  2   시설총규모       9 non-null      int64
#  3   층           9 non-null      int64
#  4   지하철역까지거리    9 non-null      float64
#  5   창업월         9 non-null      int64
#  6   자치구         9 non-null      int64
#  7   프랜차이즈여부     9 non-null      int64
#  8   인근지하철역호선    9 non-null      int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 776.0+ bytes

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold=KFold(n_splits=10, shuffle=True, random_state=0)

# %%
#kNN
clf=KNeighborsClassifier(n_neighbors=4)#개 높은데 일단 보류
scoring='accuracy'
score=cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.62725546 0.62630579 0.61965812 0.62583096 0.64150047 0.61377672
#  0.62327791 0.61472684 0.63372922 0.63942993]

# %%
round(np.mean(score)*100,2)
# Out:
# 62.65

# %%
#decision tree
clf=DecisionTreeClassifier(max_depth=5)# 프루닝을 해서 정확도 상승
scoring='accuracy'
score=cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.7331434  0.73124406 0.7317189  0.74121557 0.74169041 0.73586698
#  0.72969121 0.74109264 0.74631829 0.72066508]

# %%
round(np.mean(score)*100,2)
# Out:
# 73.53

# %%
#random forest
clf=RandomForestClassifier(n_estimators=3,max_depth=5)# 프루닝을 해서 정확도 상승
scoring='accuracy'
score=cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.7302944  0.73124406 0.7331434  0.74358974 0.74169041 0.73871734
#  0.72826603 0.72969121 0.75011876 0.71638955]

# %%
round(np.mean(score)*100,2)
# Out:
# 73.43

# %%
#naive bayes
clf=GaussianNB()
scoring='accuracy'
score=cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.71035138 0.71272555 0.70797721 0.72032289 0.73504274 0.71733967
#  0.70546318 0.71638955 0.43182898 0.70973872]

# %%
round(np.mean(score)*100,2)
# Out:
# 68.67

# %%
'''
#svm
clf=SVC()
scoring='accuracy'
score=cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
'''
# Out:
# "\n#svm\nclf=SVC()\nscoring='accuracy'\nscore=cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)\nprint(score)\n"

# %%
round(np.mean(score)*100,2)
# Out:
# 68.67

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21055 entries, 0 to 21054
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21055 non-null  int64
#  1   시설총규모       21055 non-null  float64
#  2   업소위치분기      21055 non-null  int64
#  3   distance    21055 non-null  float64
#  4   창업월         21055 non-null  int64
#  5   구_1_25      21055 non-null  int64
#  6   프랜차이즈여부_02  21055 non-null  int64
#  7   sub_19      21055 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 1.3 MB

# %%
#test!!-decision tree
clf=DecisionTreeClassifier()#max_depth=5)#
clf.fit(train_data,target)
test_data=test.drop(['사업장명'], axis=1).copy()
prediction=clf.predict(test_data)

# %%
'''
#rf
clf=RandomForestClassifier(n_estimators=5)#,max_depth=5)
clf.fit(train_data,target)
scoring='accuracy'
test_data=test.drop(['사업장명','성공여부'], axis=1).copy()
prediction=clf.predict(test_data)
'''
# Out:
# "\n#rf\nclf=RandomForestClassifier(n_estimators=5)#,max_depth=5)\nclf.fit(train_data,target)\nscoring='accuracy'\ntest_data=test.drop(['사업장명','성공여부'], axis=1).copy()\nprediction=clf.predict(test_data)\n"

# %%
submission=pd.DataFrame({'사업장명':test['사업장명'],"성공":prediction})
submission.to_csv('/content/drive/My Drive/Colab Notebooks/data_2020cafe/submission_inheo_ex.csv',index=False)

# %%
submission=pd.read_csv('/content/drive/My Drive/Colab Notebooks/data_2020cafe/submission_inheo_ex.csv')
submission.head(10)
# Out:
#   사업장명  성공
# 0  김*재   1
# 1  나*원   0
# 2  장*정   0
# 3  이*정   1
# 4  정*하   1
# 5  곽*옥   1
# 6  이*재   1
# 7  김*주   1
# 8  금*연   0

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사업장명    4 non-null      object
#  1   성공      4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      int64
#  1   사업장명        4 non-null      object
#  2   시설총규모       4 non-null      int64
#  3   층           4 non-null      int64
#  4   지하철역까지거리    4 non-null      float64
#  5   창업월         4 non-null      int64
#  6   자치구         4 non-null      int64
#  7   프랜차이즈여부     4 non-null      int64
#  8   인근지하철역호선    4 non-null      int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 416.0+ bytes

# %%
sub=pd.DataFrame(submission['성공'])
testy=pd.DataFrame(test['성공여부'])

# %%
sub.info()
sub

# %%
#testy=testy.reset_index(drop=True)
testy

# %%
df=pd.concat([sub, testy],axis=1)
df

# %%
df['scorey']=(df['성공']==df['성공여부'])

# %%
df['scorey'].value_counts()
# Out:
# True     7937
# False    1087
# Name: scorey, dtype: int64

# %%
print("제 점수는 : ",7937/9024*100)
# Out:
# 제 점수는 :  87.9543439716312
